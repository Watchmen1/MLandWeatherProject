# %%
import pandas as pd

nwdf = pd.read_pickle("./weather_data_cleaned.pkl")

# %%
nwdf = nwdf.dropna()

# %%
nwdf
# Out:
#           tempAvg  tempHigh  tempLow  tempAvg_1  tempAvg_2  tempAvg_3  \
# date
# 20180301     14.0      17.0     10.0       19.0       14.0       12.0
# 20180302     13.0      21.0      5.0       14.0       19.0       14.0
# 20180303     16.0      23.0      9.0       13.0       14.0       19.0
# 20180304     18.0      21.0     16.0       16.0       13.0       14.0
# 20180305     18.0      22.0      9.0       18.0       16.0       13.0
# ...           ...       ...      ...        ...        ...        ...
# 20201117     13.0      23.0      3.0       11.0       13.0       23.0
# 20201118     15.0      23.0      8.0       13.0       11.0       13.0
# 20201119     18.0      24.0     13.0       15.0       13.0       11.0
# 20201120     19.0      23.0     16.0       18.0       15.0       13.0
# 20201121     19.0      25.0     15.0       19.0       18.0       15.0
#
#           dewptAvg_1  dewptAvg_2  dewptAvg_3  pressureTrend_1  ...  \
# date                                                           ...
# 20180301        17.0        12.0         6.0            -2.37  ...
# 20180302         9.0        17.0        12.0            15.92  ...
# 20180303         3.0         9.0        17.0            -1.69  ...
# 20180304         6.0         3.0         9.0            -4.74  ...
# 20180305        12.0         6.0         3.0            -7.45  ...
# ...              ...         ...         ...              ...  ...
# 20201117         0.0        -3.0        17.0             0.13  ...
# 20201118         2.0         0.0        -3.0             0.03  ...
# 20201119         4.0         2.0         0.0            -0.20  ...
# 20201120        11.0         4.0         2.0            -0.09  ...
# 20201121        15.0        11.0         4.0             0.11  ...
#
#           dewptLow_3  pressureMax_1  pressureMax_2  pressureMax_3  \
# date
# 20180301         3.0        1006.43        1015.92        1019.30
# 20180302         6.0        1019.30        1006.43        1015.92
# 20180303        16.0        1022.01        1019.30        1006.43
# 20180304         1.0        1018.96        1022.01        1019.30
# 20180305         0.0        1013.55        1018.96        1022.01
# ...              ...            ...            ...            ...
# 20201117         8.0        1021.84        1019.34        1008.74
# 20201118        -8.0        1025.94        1021.84        1019.34
# 20201119        -3.0        1023.13        1025.94        1021.84
# 20201120         0.0        1018.42        1023.13        1025.94
# 20201121         2.0        1019.81        1018.42        1023.13
#
#           pressureMin_1  pressureMin_2  pressureMin_3  precipTotal_1  \
# date
# 20180301        1000.34        1005.76        1013.55          10.92
# 20180302        1002.71        1000.34        1005.76           0.00
# 20180303        1016.93        1002.71        1000.34           0.00
# 20180304        1012.53        1016.93        1002.71           0.00
# 20180305        1004.06        1012.53        1016.93           0.00
# ...                 ...            ...            ...            ...
# 20201117        1018.02        1005.52         998.44           0.00
# 20201118        1021.44        1018.02        1005.52           0.00
# 20201119        1016.93        1021.44        1018.02           0.00
# 20201120        1013.14        1016.93        1021.44           0.00
# 20201121        1015.04        1013.14        1016.93           0.00
#
#           precipTotal_2  precipTotal_3
# date
# 20180301           0.00           0.00
# 20180302          10.92           0.00
# 20180303           0.00          10.92
# 20180304           0.00           0.00
# 20180305           0.00           0.00
# ...                 ...            ...
# 20201117           0.00           0.00
# 20201118           0.00           0.00
# 20201119           0.00           0.00
# 20201120           0.00           0.00
# 20201121           0.00           0.00
#
# [714 rows x 39 columns]

# %%
nwdf.corr()[['tempAvg']].sort_values('tempAvg')
# Out:
#                   tempAvg
# pressureMax_1   -0.414341
# pressureMax_2   -0.313900
# pressureMax_3   -0.303782
# humidityLow_2   -0.215507
# humidityLow_1   -0.193182
# humidityLow_3   -0.183583
# humidityHigh_2  -0.145652
# humidityHigh_3  -0.137565
# humidityHigh_1  -0.134200
# pressureMin_1   -0.126565
# pressureTrend_1 -0.094105
# precipTotal_2   -0.061825
# precipTotal_1   -0.059699
# pressureMin_3   -0.044247
# precipTotal_3   -0.039202
# pressureMin_2   -0.030393
# pressureTrend_2 -0.003856
# pressureTrend_3  0.027660
# dewptLow_3       0.703951
# dewptHigh_3      0.718679
# dewptLow_2       0.723454
# dewptHigh_2      0.733961
# dewptAvg_3       0.734876
# dewptAvg_2       0.754257
# dewptLow_1       0.787745
# dewptHigh_1      0.805464
# tempLow_3        0.816334
# tempHigh_3       0.820093
# dewptAvg_1       0.826584
# tempAvg_3        0.838335
# tempLow_2        0.840796
# tempHigh_2       0.856502
# tempAvg_2        0.869752
# tempLow_1        0.904803
# tempHigh_1       0.914994
# tempAvg_1        0.933302
# tempLow          0.967536
# tempHigh         0.971960
# tempAvg          1.000000

# %%
predictors = ['dewptLow_1',  'dewptLow_2',  'dewptLow_3',
              'dewptHigh_1', 'dewptHigh_2', 'dewptHigh_3',
              'dewptAvg_1',  'dewptAvg_2',  'dewptAvg_3',
              'tempLow_1',   'tempLow_2',   'tempLow_3',
              'tempHigh_1',  'tempHigh_2',  'tempHigh_3',
              'tempAvg_1',   'tempAvg_2',   'tempAvg_3']
df2 = nwdf[['tempAvg'] + predictors]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# manually set the parameters of the figure to and appropriate size
plt.rcParams['figure.figsize'] = [16, 22]

# call subplots specifying the grid structure we desire and that 
# the y axes should be shared
fig, axes = plt.subplots(nrows=6, ncols=3, sharey=True)

# Since it would be nice to loop through the features in to build this plot
# let us rearrange our data into a 2D array of 6 rows and 3 columns
arr = np.array(predictors).reshape(6, 3)

# use enumerate to loop over the arr 2D array of rows and columns
# and create scatter plots of each meantempm vs each feature
for row, col_arr in enumerate(arr):
    for col, feature in enumerate(col_arr):
        axes[row, col].scatter(df2[feature], df2['tempAvg'])
        if col == 0:
            axes[row, col].set(xlabel=feature, ylabel='tempAvg')
        else:
            axes[row, col].set(xlabel=feature)
plt.show()

# %%
# import the relevant module
import statsmodels.api as sm

# separate our my predictor variables (X) from my outcome variable y
X = df2[predictors]
y = df2['tempAvg']

# Add a constant to the predictor variable set to represent the Bo intercept
X = sm.add_constant(X)
X.iloc[:5, :5]
# Out:
# /Users/watchmen1/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#           const  dewptLow_1  dewptLow_2  dewptLow_3  dewptHigh_1
# date
# 20180301    1.0        16.0         6.0         3.0         19.0
# 20180302    1.0         1.0        16.0         6.0         16.0
# 20180303    1.0         0.0         1.0        16.0          7.0
# 20180304    1.0         4.0         0.0         1.0          8.0
# 20180305    1.0         6.0         4.0         0.0         17.0

# %%
# (1) select a significance value
alpha = 0.05

# (2) Fit the model
model = sm.OLS(y, X).fit()

# (3) evaluate the coefficients' p-values
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tempAvg   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     324.8
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):          9.88e-324
# Time:                        21:33:51   Log-Likelihood:                -1746.9
# No. Observations:                 714   AIC:                             3532.
# Df Residuals:                     695   BIC:                             3619.
# Df Model:                          18
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.4529      0.612      4.006      0.000       1.251       3.655
# dewptLow_1      0.2562      0.058      4.452      0.000       0.143       0.369
# dewptLow_2      0.0232      0.060      0.383      0.702      -0.096       0.142
# dewptLow_3      0.0538      0.059      0.910      0.363      -0.062       0.170
# dewptHigh_1    -0.1814      0.071     -2.550      0.011      -0.321      -0.042
# dewptHigh_2    -0.1051      0.071     -1.484      0.138      -0.244       0.034
# dewptHigh_3     0.0339      0.067      0.507      0.613      -0.098       0.165
# dewptAvg_1     -0.1522      0.111     -1.377      0.169      -0.369       0.065
# dewptAvg_2     -0.1203      0.111     -1.086      0.278      -0.338       0.097
# dewptAvg_3     -0.0007      0.108     -0.006      0.995      -0.213       0.211
# tempLow_1       0.1564      0.081      1.932      0.054      -0.003       0.315
# tempLow_2      -0.0720      0.082     -0.878      0.380      -0.233       0.089
# tempLow_3       0.0452      0.078      0.580      0.562      -0.108       0.198
# tempHigh_1      0.2546      0.069      3.666      0.000       0.118       0.391
# tempHigh_2     -0.0025      0.073     -0.034      0.973      -0.145       0.140
# tempHigh_3     -0.0571      0.071     -0.802      0.423      -0.197       0.083
# tempAvg_1       0.5656      0.127      4.461      0.000       0.317       0.815
# tempAvg_2       0.0708      0.132      0.538      0.591      -0.188       0.329
# tempAvg_3       0.1278      0.128      1.001      0.317      -0.123       0.378
# ==============================================================================
# Omnibus:                       74.868   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.079
# Skew:                          -0.521   Prob(JB):                     8.86e-47
# Kurtosis:                       5.458   Cond. No.                         491.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# (3) cont. - Identify the predictor with the greatest p-value and assess if its > our selected alpha.
#             based off the table it is clear that meandewptm_3 has the greatest p-value and that it is
#             greater than our alpha of 0.05

# (4) - Use pandas drop function to remove this column from X
X = X.drop('dewptAvg_3', axis=1)

# (5) Fit the model 
model = sm.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tempAvg   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     344.4
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):               0.00
# Time:                        21:37:11   Log-Likelihood:                -1746.9
# No. Observations:                 714   AIC:                             3530.
# Df Residuals:                     696   BIC:                             3612.
# Df Model:                          17
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.4533      0.608      4.034      0.000       1.259       3.647
# dewptLow_1      0.2562      0.057      4.456      0.000       0.143       0.369
# dewptLow_2      0.0232      0.060      0.384      0.701      -0.095       0.142
# dewptLow_3      0.0535      0.039      1.375      0.170      -0.023       0.130
# dewptHigh_1    -0.1814      0.071     -2.552      0.011      -0.321      -0.042
# dewptHigh_2    -0.1051      0.071     -1.491      0.136      -0.244       0.033
# dewptHigh_3     0.0336      0.043      0.779      0.436      -0.051       0.118
# dewptAvg_1     -0.1522      0.110     -1.378      0.169      -0.369       0.065
# dewptAvg_2     -0.1203      0.111     -1.088      0.277      -0.337       0.097
# tempLow_1       0.1564      0.081      1.934      0.054      -0.002       0.315
# tempLow_2      -0.0720      0.082     -0.880      0.379      -0.233       0.089
# tempLow_3       0.0452      0.078      0.580      0.562      -0.108       0.198
# tempHigh_1      0.2546      0.069      3.673      0.000       0.119       0.391
# tempHigh_2     -0.0025      0.073     -0.034      0.973      -0.145       0.140
# tempHigh_3     -0.0571      0.071     -0.803      0.422      -0.197       0.083
# tempAvg_1       0.5656      0.127      4.466      0.000       0.317       0.814
# tempAvg_2       0.0709      0.131      0.540      0.589      -0.187       0.329
# tempAvg_3       0.1277      0.127      1.007      0.314      -0.121       0.377
# ==============================================================================
# Omnibus:                       74.877   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              212.138
# Skew:                          -0.521   Prob(JB):                     8.61e-47
# Kurtosis:                       5.459   Cond. No.                         480.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = X[['const','tempLow_1', 'tempLow_2', 'tempLow_3', 'dewptHigh_1', 'dewptHigh_3', 'dewptLow_1', 'tempHigh_1']]

# %%
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tempAvg   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     786.7
# Date:                Fri, 27 Nov 2020   Prob (F-statistic):               0.00
# Time:                        21:41:57   Log-Likelihood:                -1770.9
# No. Observations:                 714   AIC:                             3558.
# Df Residuals:                     706   BIC:                             3594.
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           1.7547      0.487      3.600      0.000       0.798       2.712
# tempLow_1       0.4575      0.052      8.805      0.000       0.356       0.560
# tempLow_2      -0.1412      0.046     -3.042      0.002      -0.232      -0.050
# tempLow_3       0.1508      0.045      3.333      0.001       0.062       0.240
# dewptHigh_1    -0.2959      0.044     -6.802      0.000      -0.381      -0.210
# dewptHigh_3     0.0147      0.035      0.414      0.679      -0.055       0.084
# dewptLow_1      0.1507      0.032      4.706      0.000       0.088       0.214
# tempHigh_1      0.5683      0.031     18.349      0.000       0.508       0.629
# ==============================================================================
# Omnibus:                       62.199   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              182.403
# Skew:                          -0.411   Prob(JB):                     2.46e-40
# Kurtosis:                       5.336   Cond. No.                         230.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.model_selection import train_test_split

# %%
# first remove the const column because unlike statsmodels, SciKit-Learn will add that in for us
X = X.drop('const', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
from sklearn.linear_model import LinearRegression

# %%
# instantiate the regressor class
regressor = LinearRegression()

# fit the build the model by fitting the regressor to the training data
regressor.fit(X_train, y_train)

# make a prediction set using the test set
prediction = regressor.predict(X_test)

# Evaluate the prediction accuracy of the model
from sklearn.metrics import mean_absolute_error, median_absolute_error
print("The Explained Variance: %.2f" % regressor.score(X_test, y_test))
print("The Mean Absolute Error: %.2f degress celcius" % mean_absolute_error(y_test, prediction))
# 20180622       24.0       24.0       23.0         24.0         24.0
#
#           dewptLow_1  tempHigh_1
# date
# 20201002         4.0        26.0
# 20190317       -11.0        16.0
# 20180312        -4.0        21.0
# 20190708        18.0        37.0
# 20190902        16.0        35.0
# ...              ...         ...
# 20201111         1.0        23.0
# 20180626        17.0        35.0
# 20180410         3.0        22.0
# 20190205         9.0        28.0
# 20180622        15.0        35.0
#
# [143 rows x 7 columns]

# %%
len(prediction)
# Out:
# 143

# %%
nwdf.tail(60)
# Out:
#           tempAvg  tempHigh  tempLow  tempAvg_1  tempAvg_2  tempAvg_3  \
# date
# 20200923     20.0      22.0     17.0       19.0       20.0       21.0
# 20200924     20.0      27.0     18.0       20.0       19.0       20.0
# 20200925     21.0      28.0     14.0       20.0       20.0       19.0
# 20200926     24.0      31.0     18.0       21.0       20.0       20.0
# 20200927     26.0      32.0     17.0       24.0       21.0       20.0
# 20200928     19.0      25.0     13.0       26.0       24.0       21.0
# 20200929     17.0      28.0     10.0       19.0       26.0       24.0
# 20200930     23.0      35.0     12.0       17.0       19.0       26.0
# 20201001     20.0      26.0     15.0       23.0       17.0       19.0
# 20201002     18.0      25.0     11.0       20.0       23.0       17.0
# 20201003     20.0      28.0     13.0       18.0       20.0       23.0
# 20201004     19.0      25.0     13.0       20.0       18.0       20.0
# 20201005     18.0      25.0     11.0       19.0       20.0       18.0
# 20201006     21.0      30.0     14.0       18.0       19.0       20.0
# 20201007     23.0      30.0     17.0       21.0       18.0       19.0
# 20201008     23.0      31.0     15.0       23.0       21.0       18.0
# 20201009     23.0      27.0     21.0       23.0       23.0       21.0
# 20201010     23.0      31.0     17.0       23.0       23.0       23.0
# 20201011     26.0      35.0     18.0       23.0       23.0       23.0
# 20201012     22.0      27.0     13.0       26.0       23.0       23.0
# 20201013     17.0      28.0      8.0       22.0       26.0       23.0
# 20201014     22.0      32.0     13.0       17.0       22.0       26.0
# 20201015     21.0      25.0     16.0       22.0       17.0       22.0
# 20201016     15.0      22.0     10.0       21.0       22.0       17.0
# 20201017     17.0      24.0      7.0       15.0       21.0       22.0
# 20201018     25.0      30.0     16.0       17.0       15.0       21.0
# 20201019     15.0      18.0     13.0       25.0       17.0       15.0
# 20201020     22.0      31.0     14.0       15.0       25.0       17.0
# 20201021     24.0      29.0     20.0       22.0       15.0       25.0
# 20201022     23.0      29.0     19.0       24.0       22.0       15.0
# 20201023     14.0      24.0      8.0       23.0       24.0       22.0
# 20201024     11.0      16.0      6.0       14.0       23.0       24.0
# 20201025     13.0      15.0     11.0       11.0       14.0       23.0
# 20201026      8.0      12.0      3.0       13.0       11.0       14.0
# 20201027      4.0       5.0      3.0        8.0       13.0       11.0
# 20201028      5.0       7.0      3.0        4.0        8.0       13.0
# 20201029      8.0      15.0      2.0        5.0        4.0        8.0
# 20201030     10.0      20.0      2.0        8.0        5.0        4.0
# 20201031     12.0      21.0      4.0       10.0        8.0        5.0
# 20201101     13.0      22.0      7.0       12.0       10.0        8.0
# 20201102     10.0      22.0      3.0       13.0       12.0       10.0
# 20201103     15.0      26.0      5.0       10.0       13.0       12.0
# 20201104     16.0      23.0      8.0       15.0       10.0       13.0
# 20201105     18.0      24.0     14.0       16.0       15.0       10.0
# 20201106     19.0      24.0     15.0       18.0       16.0       15.0
# 20201107     14.0      23.0     10.0       19.0       18.0       16.0
# 20201108     20.0      24.0     17.0       14.0       19.0       18.0
# 20201109     21.0      27.0     17.0       20.0       14.0       19.0
# 20201110     19.0      23.0     11.0       21.0       20.0       14.0
# 20201111     14.0      24.0      5.0       19.0       21.0       20.0
# 20201112     18.0      26.0     11.0       14.0       19.0       21.0
# 20201113     17.0      22.0     13.0       18.0       14.0       19.0
# 20201114     23.0      28.0     16.0       17.0       18.0       14.0
# 20201115     13.0      21.0      5.0       23.0       17.0       18.0
# 20201116     11.0      21.0      2.0       13.0       23.0       17.0
# 20201117     13.0      23.0      3.0       11.0       13.0       23.0
# 20201118     15.0      23.0      8.0       13.0       11.0       13.0
# 20201119     18.0      24.0     13.0       15.0       13.0       11.0
# 20201120     19.0      23.0     16.0       18.0       15.0       13.0
# 20201121     19.0      25.0     15.0       19.0       18.0       15.0
#
#           dewptAvg_1  dewptAvg_2  dewptAvg_3  pressureTrend_1  ...  \
# date                                                           ...
# 20200923        18.0        17.0        15.0            -0.12  ...
# 20200924        18.0        18.0        17.0            -0.08  ...
# 20200925        17.0        18.0        18.0            -0.01  ...
# 20200926        17.0        17.0        18.0             0.02  ...
# 20200927        19.0        17.0        17.0            -0.20  ...
# 20200928        21.0        19.0        17.0             0.02  ...
# 20200929         8.0        21.0        19.0             0.50  ...
# 20200930         6.0         8.0        21.0            -0.18  ...
# 20201001         8.0         6.0         8.0             0.03  ...
# 20201002         9.0         8.0         6.0             0.00  ...
# 20201003         6.0         9.0         8.0            -0.21  ...
# 20201004        11.0         6.0         9.0            -0.01  ...
# 20201005        10.0        11.0         6.0             0.15  ...
# 20201006        11.0        10.0        11.0            -0.20  ...
# 20201007        15.0        11.0        10.0             0.00  ...
# 20201008        16.0        15.0        11.0            -0.02  ...
# 20201009        16.0        16.0        15.0            -0.07  ...
# 20201010        20.0        16.0        16.0            -0.20  ...
# 20201011        19.0        20.0        16.0             0.02  ...
# 20201012        19.0        19.0        20.0            -0.14  ...
# 20201013        10.0        19.0        19.0             0.47  ...
# 20201014         8.0        10.0        19.0            -0.02  ...
# 20201015        15.0         8.0        10.0            -0.48  ...
# 20201016        13.0        15.0         8.0             0.70  ...
# 20201017         3.0        13.0        15.0            -0.05  ...
# 20201018        11.0         3.0        13.0            -0.41  ...
# 20201019        19.0        11.0         3.0             0.13  ...
# 20201020        11.0        19.0        11.0             0.01  ...
# 20201021        17.0        11.0        19.0            -0.04  ...
# 20201022        19.0        17.0        11.0             0.00  ...
# 20201023        19.0        19.0        17.0            -0.10  ...
# 20201024        11.0        19.0        19.0             0.46  ...
# 20201025         5.0        11.0        19.0            -0.34  ...
# 20201026        11.0         5.0        11.0             0.06  ...
# 20201027         7.0        11.0         5.0             0.20  ...
# 20201028         3.0         7.0        11.0            -0.16  ...
# 20201029         4.0         3.0         7.0            -0.29  ...
# 20201030         5.0         4.0         3.0             0.56  ...
# 20201031         4.0         5.0         4.0            -0.03  ...
# 20201101         7.0         4.0         5.0             0.00  ...
# 20201102         5.0         7.0         4.0             0.33  ...
# 20201103         3.0         5.0         7.0            -0.24  ...
# 20201104         5.0         3.0         5.0            -0.13  ...
# 20201105         8.0         5.0         3.0            -0.05  ...
# 20201106        15.0         8.0         5.0            -0.03  ...
# 20201107        14.0        15.0         8.0            -0.07  ...
# 20201108        11.0        14.0        15.0            -0.13  ...
# 20201109        17.0        11.0        14.0            -0.02  ...
# 20201110        18.0        17.0        11.0            -0.20  ...
# 20201111        11.0        18.0        17.0             0.19  ...
# 20201112         4.0        11.0        18.0             0.05  ...
# 20201113        11.0         4.0        11.0             0.05  ...
# 20201114        10.0        11.0         4.0            -0.08  ...
# 20201115        17.0        10.0        11.0            -0.13  ...
# 20201116        -3.0        17.0        10.0             0.55  ...
# 20201117         0.0        -3.0        17.0             0.13  ...
# 20201118         2.0         0.0        -3.0             0.03  ...
# 20201119         4.0         2.0         0.0            -0.20  ...
# 20201120        11.0         4.0         2.0            -0.09  ...
# 20201121        15.0        11.0         4.0             0.11  ...
#
#           dewptLow_3  pressureMax_1  pressureMax_2  pressureMax_3  \
# date
# 20200923        11.0        1011.82        1014.02        1015.14
# 20200924        15.0        1008.84        1011.82        1014.02
# 20200925        17.0        1008.94        1008.84        1011.82
# 20200926        16.0        1009.62        1008.94        1008.84
# 20200927        15.0        1007.32        1009.62        1008.94
# 20200928        14.0        1002.91        1007.32        1009.62
# 20200929        17.0        1015.04        1002.91        1007.32
# 20200930        14.0        1015.24        1015.04        1002.91
# 20201001         4.0        1010.94        1015.24        1015.04
# 20201002        -1.0        1017.03        1010.94        1015.24
# 20201003         5.0        1011.62        1017.03        1010.94
# 20201004         4.0        1005.62        1011.62        1017.03
# 20201005         2.0        1010.02        1005.62        1011.62
# 20201006         7.0        1009.82        1010.02        1005.62
# 20201007         7.0        1005.72        1009.82        1010.02
# 20201008         8.0        1005.11        1005.72        1009.82
# 20201009        11.0        1005.32        1005.11        1005.72
# 20201010        15.0        1001.52        1005.32        1005.11
# 20201011        13.0         998.44        1001.52        1005.32
# 20201012        19.0         997.22         998.44        1001.52
# 20201013        16.0        1005.22         997.22         998.44
# 20201014        17.0        1008.84        1005.22         997.22
# 20201015         3.0        1004.91        1008.84        1005.22
# 20201016         6.0        1010.02        1004.91        1008.84
# 20201017        10.0        1015.34        1010.02        1004.91
# 20201018         3.0        1009.21        1015.34        1010.02
# 20201019         1.0        1002.34        1009.21        1015.34
# 20201020         4.0        1005.52        1002.34        1009.21
# 20201021        12.0        1003.42        1005.52        1002.34
# 20201022        10.0        1004.84        1003.42        1005.52
# 20201023        12.0        1002.24        1004.84        1003.42
# 20201024        18.0        1010.33        1002.24        1004.84
# 20201025        18.0        1010.02        1010.33        1002.24
